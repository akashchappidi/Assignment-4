# %% [markdown]
# ASSIGNMENT-4
#
# Q1) What is Object-Oriented Programming (oop) ?
#
# -->Object-Oriented Programming (OOP) is a programming paradigm that organizes code around "objects" that encapsulate data (attributes) and behavior (methods). This approach promotes modularity, reusability, and maintainability of software.
#
# Q2) What is a class in OOP ?
# -->In OOP, a class is a blueprint that defines the characteristics (attributes) and behaviors (methods) of objects. It serves as a template for creating instances (objects) of that specific type.
#
# Q3) What is an object in OOP ?
# --> n OOP, an object is an instance of a class. It represents a real-world entity with its own unique set of data (attributes) and behaviors (methods) defined by the class
#
# Q4) What is the difference between abstraction and encapsulation?
# --> Abstraction: Hides implementation details, focusing on essential behavior.
# Encapsulation: Bundles data and methods, controlling access to internal state.
#
# Q5) What are dunder methods in Python?
# --> Dunder methods in Python are special methods starting and ending with __ (e.g., __init__). They customize object behavior (e.g., operator overloading, built-in function interactions) and are invoked implicitly by Python.
#
# Q6)  Explain the concept of inheritance in OOP ?
# --> that allows a new class (subclass or derived class) to inherit the properties and behaviors (attributes and methods) of an existing class (superclass or base class).
#
# Q7) What is polymorphism in OOP?
# -->Polymorphism allows objects of different classes to be treated as objects of a common type. This enables code to work with objects of various classes uniformly, promoting flexibility and reusability
#
# Q8) How is encapsulation achieved in Python ?
# --> Encapsulation in Python is achieved through access modifiers (single and double underscores). These conventions control the
#
# Q9) What is a constructor in Python ?
# --> In Python, a constructor is a special method named __init__ that is automatically called when an object of a class is created. It's used to initialize the object's attributes with initial values or perform any necessary setup actions during object creation.
#
# Q10)What are class and static methods in Python ?
# --> Class Methods: Defined using @classmethod decorator, bound to the class itself, accessed using ClassName.method_name().
# Static Methods: Defined using @staticmethod decorator, not bound to the class or instance, accessed using ClassName.method_name().
#
# Q11) What is method overloading in Python?
# --> Python doesn't directly support method overloading. Achieve similar behavior using default arguments, variable-length arguments (*args, **kwargs), or consider alternative approaches like polymorphism.
#
# Q12) What is method overriding in OOP?
# --> Method overriding allows a subclass to provide its own implementation for a method inherited from its parent class, enabling customization of behavior while maintaining the same method signature.
#
# Q13) What is a property decorator in Python?
# --> The @property decorator in Python lets you define methods that behave like attributes. This enhances encapsulation by controlling attribute access and modification, enabling features like data validation and computed properties.
#
# Q14) Why is polymorphism important in OOP?
# -->Polymorphism enhances code reusability and flexibility by enabling code to work with objects of different classes uniformly, making it easier to adapt to changes and reducing code redundancy.
#
# Q15) What is an abstract class in Python?
# --> An abstract class in Python is a blueprint that cannot be instantiated directly. It defines a common interface and forces subclasses to implement specific methods, promoting a standardized structure and behavior.
#
# Q16) What are the advantages of OOP?
# --> OOP offers modularity, reusability, flexibility, data encapsulation, and improved code organization. This leads to more efficient, maintainable, and scalable software systems.
#
# Q17) What is the difference between a class variable and an instance variable?
# --> Instance Variable: Unique to each object of a class, defined within methods (like __init__).
# Class Variable: Shared among all instances of a class, defined directly within the class.
#
# Q18) What is multiple inheritance in Python?
#
# --> Multiple inheritance allows a class to inherit from multiple parent classes, increasing flexibility but potentially leading to complex relationships and the "diamond problem."
#
# Q19) Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# -->__str__ provides a user-friendly string representation of an object.
# __repr__ provides an unambiguous string representation for developers and debugging
#
# Q20) What is the significance of the ‘super()’ function in Python?
# --> The super() function in Python allows you to call methods of the parent class within a child class, enabling method overriding and proper handling of multiple inheritance.
#
# Q21) What is the significance of the __del__ method in Python ?
# --> The __del__ method in Python is a destructor that's called when an object is about to be garbage collected. Its primary purpose is to perform necessary cleanup actions, such as closing files or releasing external resources.
#
# Q22) What is the difference between @staticmethod and @classmethod in Python
# -->@staticmethod: No implicit self or cls; behaves like a regular function but defined within a class.
# @classmethod: Receives cls (the class) as the first argument; can access and modify class attributes.
#
# Q23) How does polymorphism work in Python with inheritance ?
# -->In Python, polymorphism allows objects of different classes to be treated as objects of a common type (their parent class). This is achieved through method overriding, where child classes provide their own specific implementations of methods defined in the parent class.
#
# Q24)What is method chaining in Python OOP
# --> Method chaining in Python allows you to call multiple methods on an object in a single line. Each method returns the object itself, enabling subsequent method calls in a fluent and concise manner.
#
# Q25)What is the purpose of the __call__ method in Python.?
# --> he __call__ method in Python enables you to create callable objects. By defining this method within a class, you can treat instances of that class as functions, allowing you to call them directly.

# %%
'''
#Q1) Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".


class Animal:
  def speak(self):
    print("Generic message")

class dog(Animal):
  def speak(self):
    print("bark!")

a = Animal()
a2 = dog()
a2.speak()



Q2)  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

import abc
class shape:
    @abc.abstractmethod

    def area(self):
        pass

class rec(shape):
    def area(self,l,b):
        self.l = l
        self.b = b
        return l*b

class circle(shape):
    def area(self,r):
        self.r = r
        return 2*1.4*r

a = circle()

a.area(2)

Q3)  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class vehicle:
  def type(self):
    print("i am vehicle")

class car(vehicle):
  def car_info(self):
    print("car is working")

class electriccar(car):
  def battery(self):
    print("battery is ok")


a = electriccar()
a.type()
a.car_info()
a.battery()

Q4) Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class vehicle:
  def type(self):
    print("i am vehicle")

class car(vehicle):
  def car_info(self):
    print("car is working")

class electriccar(car):
  def battery(self):
    print("battery is ok")


a = electriccar()
a.type()
a.car_info()
a.battery()


Q5) . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance
class bank:
    def __init__(self,balance):
        self.__balance = balance
    def deposite(self,amount):
        self.__balance = self.__balance + amount
    def withdraw(self,amount):
        self.__balance = self.__balance - amount
    def money(self):
        return self.__balance

a = bank(1000)
a._bank__balance
a.deposite(200)
a._bank__balance
a.withdraw(700)
a._bank__balance

Q6)Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):


class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar...")

class Piano(Instrument):
    def play(self):
        print("Playing a melody on the piano...")


guitar = Guitar()
piano = Piano()


for instrument in [guitar, piano]:
    instrument.play()







Q7)  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class

class cal:
    @staticmethod
    def add(x,y):
        return x+y
    def sub(a,b):
        return a-b
a = cal()
a.add(2,3)

Q8)  Implement a class Person with a class method to count the total number of persons created

class student:
  lass student:

    total=0
    def __init__(self,name):
        self.name = name
        student.total += 1

    @classmethod
    def name(self):
        return student.total


stu = student("akash")
stu =  student("akash")
stu.total

Q9)  Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
--> class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage:
fraction1 = Fraction(3, 4)
fraction2 = Fraction(1, 2)

print(fraction1)  # Output: 3/4
print(fraction2)

Q10) Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
-->class vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __add__(self,other):
        return vector(self.x + other.x , self.y + other.y)

    def access(self):
        return self.x + self.y


c = vector(2,3)
c1 = vector(2,3)
c2 = c + c1
print(c2.x,c2.y)


Q11) . Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def greet(self):
        return f"Hello my name is ({self.name}) and i am ({self.age}) years old "

a = person("akash",55)
a.greet()

Q12) Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
   -->class Student:
    def __init__(self, name, grades):
        """
        Initializes a Student object with the given name and grades.

        Args:
            name (str): The name of the student.
            grades (list): A list of numerical grades.
        """
        self.name = name
        self.grades = grades

    def average_grade(self):
        """
        Calculates the average of the student's grades.

        Returns:
            float: The average grade.
        """
        if not self.grades:
            return 0  # Handle the case of no grades
        return sum(self.grades) / len(self.grades)

# Example usage:
student1 = Student("Alice", [90, 85, 92, 88])
student2 = Student("Bob", [78, 82, 75])

print(f"{student1.name}'s average grade: {student1.average_grade()}")
print(f"{student2.name}'s average grade: {student2.average_grade()}")
Q13) Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class rectangle:

    def set_dimension(self,l,b):
        self.l = l
        self.b = b
    def area(self):
        return self.l* self.b

s = rectangle()
s.set_dimension(2,3)
s.area()

Q14) Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class employee:
    def cal_salary(self,hours,rate):
        self.hours = hours
        self.rate = rate
        return self.hours * self.rate
class manager(employee):
    def bonus(self,bonus):
        self.bonus = bonus

    def all(self):
        return self.bonus + self.hours * self.rate


c = manager()
c.bonus(1000)
c.cal_salary(7,100)
c.all()


Q15) 5. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
-->class product:
    def total_price(self,name,price,quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
        return self.price * self.quantity

s = product()
s.total_price("ak",2,3)

Q16) Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
-->import abc
class animal:
    @abc.abstractmethod
    def sound(self):
        print("this is animal sound")
class cow(animal):
    def sound(self):
        print("ambaaaaa")
class sheep(animal):
    def sound(self):
        print("mememem")

a = cow()
a.sound()
b=sheep()
b.sound()

Q17) Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class book:
    def get_book(self,title,author,year):
        self.title = title
        self.author = author
        self.year = year
    def access(self):
        print(self.title,self.author,self.year)

c = book()
c.get_book("erihuka","shakesphere",1967)
c.access()

Q18)  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class house:
    def ss(self,price,address):
        self.price = price
        self.address = address
        return self.price,self.address
class mansion(house):
    def aa(self,rooms):
        self.rooms = rooms
        return self.rooms

o = mansion()
o.aa(5)
o.ss(234,"hyderabad near pragathi nagar")






'''
